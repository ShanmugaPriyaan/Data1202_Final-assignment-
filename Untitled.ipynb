# %%
#Load libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#Load the data set
Finalass_data =pd.read_csv('survey.csv')
Finalass_data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
#List the columns in the dataset
list(Finalass_data.columns)
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence',
#  'comments']

# %%
#Drop the self_employed column
Finalass_data1=Finalass_data.drop(['self_employed'], axis=1)
Finalass_data1.head()
# Out:
#              Timestamp  Age  Gender         Country state family_history  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL             No
# 1  2014-08-27 11:29:37   44       M   United States    IN             No
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN             No
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN            Yes
# 4  2014-08-27 11:30:22   31    Male   United States    TX             No
#
#   treatment work_interfere    no_employees remote_work  ...  \
# 0       Yes          Often            6-25          No  ...
# 1        No         Rarely  More than 1000          No  ...
# 2        No         Rarely            6-25          No  ...
# 3       Yes          Often          26-100          No  ...
# 4        No          Never         100-500         Yes  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
# Count Function 
def function(country,column_name):
    country_data=Finalass_data1[Finalass_data1['Country'].str.contains(country)]
    country_data = country_data.groupby([column_name])[column_name].count().reset_index(name="count")
    return country_data.plot.bar(x=column_name)

# %%
#Extract only rows with treatment set to "Yes"
treatmentvalue_positive=Finalass_data1[Finalass_data1['treatment'].str.contains("Yes")]
treatmentvalue_positive.head()
# Out:
#               Timestamp  Age  Gender         Country state family_history  \
# 0   2014-08-27 11:29:31   37  Female   United States    IL             No
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN            Yes
# 6   2014-08-27 11:31:50   35  Female   United States    MI            Yes
# 8   2014-08-27 11:32:39   42  Female   United States    IL            Yes
# 10  2014-08-27 11:32:44   31    Male   United States    OH             No
#
#    treatment work_interfere no_employees remote_work  ...               leave  \
# 0        Yes          Often         6-25          No  ...       Somewhat easy
# 3        Yes          Often       26-100          No  ...  Somewhat difficult
# 6        Yes      Sometimes          1-5         Yes  ...  Somewhat difficult
# 8        Yes      Sometimes      100-500          No  ...      Very difficult
# 10       Yes      Sometimes         6-25         Yes  ...          Don't know
#
# ...

# %%
#Plot the graph showing the mental health by global location with treatment set to "YES"
mentalhealth_treat_positive.plot.bar()

# %%
function('United States','benefits')

# %%
function('United Kingdom','benefits')

# %%
#Getting United kindom data
country_uk_WP = treatmentvalue_positive[treatmentvalue_positive['Country'].str.contains("United Kingdom")]
country_uk_WP.head()
# Out:
#               Timestamp  Age Gender         Country state family_history  \
# 3   2014-08-27 11:29:46   31   Male  United Kingdom   NaN            Yes
# 16  2014-08-27 11:34:20   23   Male  United Kingdom   NaN             No
# 32  2014-08-27 11:39:31   30   male  United Kingdom   NaN            Yes
# 40  2014-08-27 11:42:25   24   Male  United Kingdom   NaN             No
# 86  2014-08-27 12:07:08   39   Male  United Kingdom   NaN             No
#
#    treatment work_interfere no_employees remote_work  ...               leave  \
# 3        Yes          Often       26-100          No  ...  Somewhat difficult
# 16       Yes      Sometimes       26-100         Yes  ...           Very easy
# 32       Yes      Sometimes     500-1000         Yes  ...       Somewhat easy
# 40       Yes      Sometimes         6-25          No  ...          Don't know
# 86       Yes          Often         6-25          No  ...      Very difficult
#
# ...

# %%
#Getting count for the column wellness_program for UK only
country_uk_WP1 = country_uk_WP.groupby(['wellness_program'])['wellness_program'].count().reset_index(name="count")
country_uk_WP1.head()
# Out:
#   wellness_program  count
# 0       Don't know     10
# 1               No     70
# 2              Yes     13

# %%
#Getting United States data
country_us_WP = treatmentvalue_positive[treatmentvalue_positive['Country'].str.contains("United States")]
country_us_WP.head()
# Out:
#               Timestamp  Age  Gender        Country state family_history  \
# 0   2014-08-27 11:29:31   37  Female  United States    IL             No
# 6   2014-08-27 11:31:50   35  Female  United States    MI            Yes
# 8   2014-08-27 11:32:39   42  Female  United States    IL            Yes
# 10  2014-08-27 11:32:44   31    Male  United States    OH             No
# 12  2014-08-27 11:33:23   42  female  United States    CA            Yes
#
#    treatment work_interfere no_employees remote_work  ...               leave  \
# 0        Yes          Often         6-25          No  ...       Somewhat easy
# 6        Yes      Sometimes          1-5         Yes  ...  Somewhat difficult
# 8        Yes      Sometimes      100-500          No  ...      Very difficult
# 10       Yes      Sometimes         6-25         Yes  ...          Don't know
# 12       Yes      Sometimes       26-100          No  ...  Somewhat difficult
#
# ...

# %%
#Getting count for the column wellness_program for US only
country_us_WP1 = country_us_WP.groupby(['wellness_program'])['wellness_program'].count().reset_index(name="count")
country_us_WP1.head()
# Out:
#   wellness_program  count
# 0       Don't know     59
# 1               No    255
# 2              Yes     96

# %%
#Plot the histogram to show the wellness program in UK
country_uk_WP1.plot.bar(x='wellness_program')

# %%
#Plot the histogram to show the wellness program in US
country_us_WP1.plot.bar(x='wellness_program')
